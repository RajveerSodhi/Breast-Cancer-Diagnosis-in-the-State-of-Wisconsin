# %% [markdown]
# # Mithish Ravisankar Geetha

# %% [markdown]
# ## Research question/interests
#
# Briefly describe your research question or interests here.
#
# ### 1. Based on the features of several key features (for example radius and texture), can we accurately identify whether the tumour being benign or malignant?
#
#
# For this question, I plan to use a variety of pandas operations to find out if the cancer is benign or malignant. This can be done by investigating the distribution and connection between the features and diagnosis using visualisation techniques like histograms, box plots, and scatter plots.  To compare the distribution of the essential characteristics between the benign and malignant groups, box plots or histograms can be made. This method of data analysis and visualisation allows us to spot any patterns or connections between the primary characteristics and the classification of a tumour as benign or malignant.
#
#
# ### 2. Are there any outlier values in the dataset? How do they affect our understanding of the relationship between key features and diagnosis?
# We can use a variety of data analysis and visualization techniques to answer this question. One possible way is to create a box plot for several features in the dataset and then calculate the outliers in the dataset. After calculating the outliers for each feature with respect to the tumour being malignant or benign, we can compare the distribution of each feature values for each diagnosis and see if there are any significant differences. Through this, we can find out if these are valid data points and effectively help doctors take the necessary action.

# %% [markdown]
# ## Loading Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import func
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 5
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 5 import func
#
# ModuleNotFoundError: No module named 'func'

# %%
df= project_functions1.load_and_process('../data/raw/data.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 df= project_functions1.load_and_process('../data/raw/data.csv')
#
# NameError: name 'project_functions1' is not defined

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
#  32  Unnamed: 32              0 non-null      float64
# dtypes: float64(31), int64(1), object(1)
# memory usage: 146.8+ KB

# %% [markdown]
# On analysing the different parameters found in the dataset, it can be said that the "id" and "Unnamed:32" columns are not
# required for our analysis.

# %%
df_new = df.copy().drop(['id','Unnamed: 32'], axis=1)
df_new
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0           0.2419  ...        25.380          17.33           184.60
# 1           0.1812  ...        24.990          23.41           158.80
# 2           0.2069  ...        23.570          25.53           152.50
# 3           0.2597  ...        14.910          26.50            98.87
# 4           0.1809  ...        22.540          16.67           152.20
# ..             ...  ...           ...            ...              ...
# 564         0.1726  ...        25.450          26.40           166.10
# 565         0.1752  ...        23.690          38.25           155.00
# 566         0.1590  ...        18.980          34.12           126.70
# 567         0.2397  ...        25.740          39.42           184.60
# 568         0.1587  ...         9.456          30.37            59.16
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0        2019.0           0.16220            0.66560           0.7119
# 1        1956.0           0.12380            0.18660           0.2416
# 2        1709.0           0.14440            0.42450           0.4504
# 3         567.7           0.20980            0.86630           0.6869
# 4        1575.0           0.13740            0.20500           0.4000
# ..          ...               ...                ...              ...
# 564      2027.0           0.14100            0.21130           0.4107
# 565      1731.0           0.11660            0.19220           0.3215
# 566      1124.0           0.11390            0.30940           0.3403
# 567      1821.0           0.16500            0.86810           0.9387
# 568       268.6           0.08996            0.06444           0.0000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [569 rows x 31 columns]

# %%
df_new.describe(exclude=np.number)
# Out:
#        diagnosis
# count        569
# unique         2
# top            B
# freq         357

# %%
df_new.describe().apply(lambda s: s.apply(lambda x: format(x, 'f')))
# Out:
#       radius_mean texture_mean perimeter_mean    area_mean smoothness_mean  \
# count  569.000000   569.000000     569.000000   569.000000      569.000000
# mean    14.127292    19.289649      91.969033   654.889104        0.096360
# std      3.524049     4.301036      24.298981   351.914129        0.014064
# min      6.981000     9.710000      43.790000   143.500000        0.052630
# 25%     11.700000    16.170000      75.170000   420.300000        0.086370
# 50%     13.370000    18.840000      86.240000   551.100000        0.095870
# 75%     15.780000    21.800000     104.100000   782.700000        0.105300
# max     28.110000    39.280000     188.500000  2501.000000        0.163400
#
#       compactness_mean concavity_mean concave points_mean symmetry_mean  \
# count       569.000000     569.000000          569.000000    569.000000
# mean          0.104341       0.088799            0.048919      0.181162
# std           0.052813       0.079720            0.038803      0.027414
# min           0.019380       0.000000            0.000000      0.106000
# 25%           0.064920       0.029560            0.020310      0.161900
# 50%           0.092630       0.061540            0.033500      0.179200
# 75%           0.130400       0.130700            0.074000      0.195700
# max           0.345400       0.426800            0.201200      0.304000
#
#       fractal_dimension_mean  ... radius_worst texture_worst perimeter_worst  \
# count             569.000000  ...   569.000000    569.000000      569.000000
# mean                0.062798  ...    16.269190     25.677223      107.261213
# std                 0.007060  ...     4.833242      6.146258       33.602542
# min                 0.049960  ...     7.930000     12.020000       50.410000
# 25%                 0.057700  ...    13.010000     21.080000       84.110000
# 50%                 0.061540  ...    14.970000     25.410000       97.660000
# 75%                 0.066120  ...    18.790000     29.720000      125.400000
# max                 0.097440  ...    36.040000     49.540000      251.200000
#
#         area_worst smoothness_worst compactness_worst concavity_worst  \
# count   569.000000       569.000000        569.000000      569.000000
# mean    880.583128         0.132369          0.254265        0.272188
# std     569.356993         0.022832          0.157336        0.208624
# min     185.200000         0.071170          0.027290        0.000000
# 25%     515.300000         0.116600          0.147200        0.114500
# 50%     686.500000         0.131300          0.211900        0.226700
# 75%    1084.000000         0.146000          0.339100        0.382900
# max    4254.000000         0.222600          1.058000        1.252000
#
#       concave points_worst symmetry_worst fractal_dimension_worst
# count           569.000000     569.000000              569.000000
# mean              0.114606       0.290076                0.083946
# std               0.065732       0.061867                0.018061
# min               0.000000       0.156500                0.055040
# 25%               0.064930       0.250400                0.071460
# 50%               0.099930       0.282200                0.080040
# 75%               0.161400       0.317900                0.092080
# max               0.291000       0.663800                0.207500
#
# [8 rows x 30 columns]

# %%
fig=sns.countplot(x='diagnosis', data=df_new.replace({'diagnosis': {'M': 'Malignant', 'B': 'Benign'}}))
plt.title('Diagnosis Count')
fig.bar_label(fig.containers[0], label_type='center', size=13)
plt.xlabel("Diagnosis Type")
plt.ylabel("Number of cases")
# Out:
# Text(0, 0.5, 'Number of cases')

# %% [markdown]
# **This shows that most of the diagnosis are benign**

# %%
features = df_new[['diagnosis', 'perimeter_mean', 'radius_mean', 'texture_mean']]
fig=sns.pairplot(data=features, hue='diagnosis')
fig.axes[0, 0].set_ylabel('Perimeter Mean')
fig.axes[1, 0].set_ylabel('Radius Mean')
fig.axes[2, 0].set_ylabel('Texture Mean')
fig.axes[2, 0].set_xlabel('Perimeter Mean')
fig.axes[2, 1].set_xlabel('Radius Mean')
fig.axes[2, 2].set_xlabel('Texture Mean')
plt.title("Comparison of Mean Texture, Perimeter and Radius for different types of Diagnosis",x=-0.35,y=-0.5)
plt.show()

# %% [markdown]
# **It can be inferred that Malignant tumors have higher values for the radius, texture and perimeter features compared to
# benign tumors.**

# %%
fig=sns.jointplot(x='radius_mean', y='diagnosis', data=df_new, height=8)
plt.xlabel("Mean Radius")
plt.ylabel("Type of diagnosis")
fig.ax_joint.set_yticklabels(['Malignant', 'Benign'])
plt.suptitle('Relationship between mean radius and diagnosis type', y=1.05)
plt.show()
# Out:
# /var/folders/b1/yj22wy75115cyfk8k2z1phs40000gn/T/ipykernel_19809/2925032000.py:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   fig.ax_joint.set_yticklabels(['Malignant', 'Benign'])

# %% [markdown]
# **On analyzing the joint plot, it can be identified that most Malignant diagnosis  have a higher radius, while most Benign diagnosis have lower radius.**

# %%
sns.violinplot(x='diagnosis', y='area_mean', data=df_new)
plt.title('Distribution of Area of tumour by diagnosis')
plt.xlabel('Type of Diagnosis')
plt.ylabel('Mean Area')
plt.gca().set_xticklabels(['Malignant', 'Benign'])
plt.show()

# %% [markdown]
# **It can be understood that the area of the tumour is wider for malignant cases and narrow for the benign cases**

# %%
fig=sns.pairplot(df[["concavity_mean", "smoothness_mean", "texture_mean","diagnosis"]],hue="diagnosis")
fig.axes[0, 0].set_ylabel('Concavity Mean')
fig.axes[1, 0].set_ylabel('Smoothness Mean')
fig.axes[2, 0].set_ylabel('Texture Mean')
fig.axes[2, 0].set_xlabel('Concavity Mean')
fig.axes[2, 1].set_xlabel('Smoothness Mean')
fig.axes[2, 2].set_xlabel('Texture Mean')
plt.suptitle("Comparison of Mean Texture, Perimeter and Radius for different types of Diagnosis",y=1.05)

plt.show()

# %% [markdown]
# **On analyzing the pairplots, we can notice that a weak negative association between the two features can be seen in the scatter plot between the concavity and smoothness values. As the concavity value decreases, the smoothness value increases**

# %% [markdown]
# **According to the diagonal graph, it is seen that the smoothness features has a normal distribution, the concavity and texture features have distributions that are right-skewed.**
